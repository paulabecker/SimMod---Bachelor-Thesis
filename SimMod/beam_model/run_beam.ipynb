# %%
from beam_carbon.beam import BEAMCarbon

# %%
# Initialize the beam model class
beam = BEAMCarbon(emissions=[10., 13., 15.,],
                  time_step=10,
                  intervals=100)

# Overwrite parameters
# beam.emissions = [10., 13., 15., ]
# beam.time_step = 10
# beam.intervals = 100

beam.run()
# Out:
#                            0             10            20            30
# mass_atmosphere    808.900000    903.638773   1027.608512   1171.367512
# mass_upper         725.000000    729.541725    734.613082    739.642104
# mass_lower       35641.000000  35641.719501  35642.678407  35643.890384
# temp_atmosphere      0.730700      1.158172      1.590403      2.029882
# temp_ocean           0.006800      0.042995      0.098754      0.173336
# phi12                0.216956      0.240174      0.271217      0.308066
# phi22               -0.266956     -0.290174     -0.321217     -0.358066
# cumulative           0.000000    200.000000    460.000000    760.000000
# A                    0.000000    142.743611    142.914257    143.177330
# B                    0.000000      0.008413      0.009489      0.010758
