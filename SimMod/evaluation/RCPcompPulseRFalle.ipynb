# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import plot functions
from utils import load_data, lineplot, lineplots_on_grid

# %%
TAG26 = "200810-130338-pulse_response-rcp26"

# Read in the pd.DataFrame
data26 = load_data(TAG26)

# Import RCP data
data_ref26 = pd.read_table("../results/RCP3PD_MIDYEAR_RADFORCING.DAT",
                      skiprows=59, sep='\s+')

TAG45 = "200809-183506-pulse_response-rcp45"

# Read in the pd.DataFrame
data45 = load_data(TAG45)

# Import RCP data
data45_ref = pd.read_table("../results/RCP45_MIDYEAR_RADFORCING.DAT",
                      skiprows=59, sep='\s+') 

TAG6 = "200810-132906-pulse_response-rcp60"

# Read in the pd.DataFrame
data6 = load_data(TAG6)

# Import RCP data
data_ref6 = pd.read_table("../results/RCP6_MIDYEAR_RADFORCING.DAT",
                      skiprows=59, sep='\s+')

TAG85 = "200809-183227-pulse_response-rcp85"

# Read in the pd.DataFrame
data85 = load_data(TAG85)

# Import RCP data
data85_ref = pd.read_table("../results/RCP85_MIDYEAR_RADFORCING.DAT",
                      skiprows=59, sep='\s+')

# %% [markdown]
# ## total forcing GHG

# %%
#2.6 
#choose CMIP5 data
keep_ref = data_ref26[data_ref26['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref26 = keep_ref['YEARS']
rf_ghg_ref26 = keep_ref['CO2CH4N2O_RF']

# choose SimMod data
keep = data26[data26['year']>1999]
time26 = keep['year']
rf_ghg26 = keep['total_forcing_ghg']

# %%
#4.5
# choose CMIP5 data
keep_ref = data45_ref[data45_ref['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref45 = keep_ref['YEARS']
rf_ghg_ref45 = keep_ref['CO2CH4N2O_RF']

# choose SimMod data
keep = data45[data45['year']>1999]
time45 = keep['year']
rf_ghg45 = keep['total_forcing_ghg']

# %%
# 6.0
# choose RCP data
keep_ref = data_ref6[data_ref6['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref6 = keep_ref['YEARS']
rf_ghg_ref6 = keep_ref['CO2CH4N2O_RF']

# choose SimMod data
keep = data6[data6['year']>1999]
time6 = keep['year']
rf_ghg6 = keep['total_forcing_ghg']

# %%
#8.5
# choose CMIP5 data
keep_ref = data85_ref[data85_ref['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref85 = keep_ref['YEARS']
rf_ghg_ref85 = keep_ref['CO2CH4N2O_RF']

# choose SimMod data
keep = data85[data85['year']>1999]
time85 = keep['year']
rf_ghg85 = keep['total_forcing_ghg']

# %%
# SimMod, CMIP5 2.6
plt.plot(time26, rf_ghg26, ls = 'dashed', c = 'b')
plt.plot(time_ref26, rf_ghg_ref26, c= 'b')

# SimMod, CMIP5 4.5
plt.plot(time45, rf_ghg45, ls = 'dashed', c = 'r')
plt.plot(time_ref45, rf_ghg_ref45, c= 'r')

# SimMod, CMIP5 6.0
plt.plot(time6, rf_ghg6, ls = 'dashed', c= 'k')
plt.plot(time_ref6, rf_ghg_ref6, c= 'k')

# SimMod, CMIP5 8.5
plt.plot(time85, rf_ghg85, ls = 'dashed', c= 'c')
plt.plot(time_ref85, rf_ghg_ref85, c= 'c')

plt.title("SimMod, CMIP5: GHG RF for RCP")
plt.xlabel("year")
plt.ylabel("W/m^2")
# Out:
# Text(0,0.5,'W/m^2')

# %% [markdown]
# # total anthropogenic forcing

# %%
# 2.6
# choose RCP data
keep_ref = data_ref26[data_ref26['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref26 = keep_ref['YEARS']
rf_ghg_ref26 = keep_ref['TOTAL_ANTHRO_RF']

# choose SimMod data
keep = data26[data26['year']>1999]
time26 = keep['year']
rf_ghg26 = keep['total_forcing']

# %%
# 4.5
# choose RCP data
keep_ref = data45_ref[data45_ref['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref45 = keep_ref['YEARS']
rf_ghg_ref45 = keep_ref['TOTAL_ANTHRO_RF']

# choose SimMod data
keep = data45[data45['year']>1999]
time45 = keep['year']
rf_ghg45 = keep['total_forcing']

# %%
# 6.0
# choose RCP data
keep_ref = data_ref6[data_ref6['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref6 = keep_ref['YEARS']
rf_ghg_ref6 = keep_ref['TOTAL_ANTHRO_RF']

# choose SimMod data
keep = data6[data6['year']>1999]
time6 = keep['year']
rf_ghg6 = keep['total_forcing']

# %%
# 8.5
# choose RCP data
keep_ref = data85_ref[data85_ref['YEARS']>1999]
keep_ref = keep_ref[keep_ref['YEARS']<2100]
time_ref85 = keep_ref['YEARS']
rf_ghg_ref85 = keep_ref['TOTAL_ANTHRO_RF']

# choose SimMod data
keep = data85[data85['year']>1999]
time85 = keep['year']
rf_ghg85 = keep['total_forcing']

# %%
# SimMod, CMIP5 2.6 
plt.plot(time26, rf_ghg26, ls = 'dashed', c= 'b')
plt.plot(time_ref26, rf_ghg_ref26, c= 'b')

# SimMod, CMIP5 4.5
plt.plot(time45, rf_ghg45, ls = 'dashed', c= 'r')
plt.plot(time_ref45, rf_ghg_ref45, c= 'r')

# SimMod, CMIP5 6.0
plt.plot(time6, rf_ghg6, ls = 'dashed', c= 'k')
plt.plot(time_ref6, rf_ghg_ref6, c= 'k')

# SimMod, CMIP5 8.5
plt.plot(time85, rf_ghg85, ls = 'dashed', c= 'c')
plt.plot(time_ref85, rf_ghg_ref85, c= 'c')

plt.title("SimMod: total RF, CMIP5: total anthropogenic RF")
plt.xlabel("year")
plt.ylabel("W/m^2")
