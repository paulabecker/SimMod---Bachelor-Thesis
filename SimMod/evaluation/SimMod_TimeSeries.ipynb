# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 15

# Import plot functions
from utils import load_data, lineplot, lineplots_on_grid

TAG = "200813-171618-pulse_response-rcp85"
#TAG_nonorm = "200813-171732-pulse_response-rcp85"

# Read in the pd.DataFrame
data = load_data(TAG)
#data_nonorm = load_data(TAG_nonorm)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'year', 'co2_pg', 'ch4_tg', 'n2o_tg',
#        'hist_forcing_wm2', 'co2_forcing_rcp', 'ch4_forcing_rcp',
#        'n2o_forcing_rcp', 'total_forcing_rcp', 'rcp_co2_ppm', 'rcp_ch4_ppb',
#        'rcp_n2o_ppb', 'co2_pg_atm', 'ch4_tg_atm', 'n2o_tg_atm',
#        'ch4_co2_decay_marginal', 'co2_ppm', 'ch4_ppb', 'n2o_ppb',
#        'co2_forcing', 'ch4_forcing', 'n2o_forcing', 'total_forcing_ghg',
#        'rcp_nonghg_forcing', 'historic_nonghg_forcings', 'total_forcing',
#        't_os', 't_eq', 't_s'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(data['year'], data['total_forcing_ghg'])
ax.plot(data['year'], data['total_forcing'])
#ax.plot(data['year'], data['t_eq'])
#ax.plot(data['year'], data['co2_pg_atm'])
#ax.plot(data['year'], data['co2_pg'])
#ax.plot(data_nonorm['year'], data_nonorm['co2_ppm'])
#ax.plot(data['year'], data['co2_ppm']-data_nonorm['co2_ppm'])
#plt.xlim(1765, 2100)
#plt.ylim(None, 0.5)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(data['year'], data['t_s'])
ax.plot(data['year'], data['t_eq'])
#ax.plot(data['year'], data['co2_pg_atm'])
#ax.plot(data['year'], data['co2_pg'])
#ax.plot(data_nonorm['year'], data_nonorm['co2_ppm'])
#ax.plot(data['year'], data['co2_ppm']-data_nonorm['co2_ppm'])
#plt.xlim(1765, 2100)
#plt.ylim(None, 0.5)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(data['year'], data['t_s'])
ax.plot(data_nonorm['year'], data_nonorm['t_s'])
#ax.plot(data['year'], data['t_s']-data_nonorm['t_s'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ce888562b750> in <module>
#       1 fig, ax = plt.subplots(figsize=(8,5))
#       2 ax.plot(data['year'], data['t_s'])
# ----> 3 ax.plot(data_nonorm['year'], data_nonorm['t_s'])
#       4 #ax.plot(data['year'], data['t_s']-data_nonorm['t_s'])
#
# NameError: name 'data_nonorm' is not defined

# %%
(data.keys())
# Out:
# Index(['Unnamed: 0', 'date', 'year', 'co2_pg', 'ch4_tg', 'n2o_tg',
#        'hist_forcing_wm2', 'co2_forcing_rcp', 'ch4_forcing_rcp',
#        'n2o_forcing_rcp', 'total_forcing_rcp', 'rcp_co2_ppm', 'rcp_ch4_ppb',
#        'rcp_n2o_ppb', 'co2_pg_atm', 'ch4_tg_atm', 'n2o_tg_atm',
#        'ch4_co2_decay_marginal', 'co2_ppm', 'ch4_ppb', 'n2o_ppb',
#        'co2_forcing', 'ch4_forcing', 'n2o_forcing', 'total_forcing_ghg',
#        'rcp_nonghg_forcing', 'historic_nonghg_forcings', 'total_forcing',
#        't_os', 't_eq', 't_s'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(data['total_forcing_ghg'], data['t_s'], s=4)
ax.scatter(data['total_forcing'], data['t_s'], s=4)
#ax.plot(data['total_forcing'], 0.6*data['total_forcing'], c='r')
ax.grid()
ax.set_xlabel("Total forcing")
ax.set_ylabel("T_s")
plt.show()

# %%
# Perform a single lineplot
fig, ax = lineplot(data, x_data='year', y_data='total_forcing_rcp')

# %%
# Arange multiple lineplots on a grid
fig, axes = lineplots_on_grid(data,
                              x_data='year',
                              y_data='_all', # use '_all' to plot all columns of the data frame
                              nrows=11, ncols=3,
                              subplot_kwargs=dict(figsize=(13,40)) # provide kwargs via dictionaries
                             )

# %%
# Again for some specific data
fig, axes = lineplots_on_grid(data,
                              x_data='year',
                              y_data=['total_forcing_rcp', 'co2_ppm', 't_s'], # providing a list of labels
                              nrows=3, ncols=1,
                              subplot_kwargs=dict(figsize=(10,8))
                             )
